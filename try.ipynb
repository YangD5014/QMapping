# %%
from qiskit.providers import QubitProperties
import sys
import pandas as pd
sys.path.append('..')
from cqlib.utils import QcisToQasm
from qiskit import  qasm2
from mqt import qmap
from tool import solve
from tool import  QSIC2QCircuit
import json
from Initial_map import find_best_mapping

# %%
with open('./XEB测试集/XEB/XEB_3_qubits/XEB_3_qubits_16_cycles_circuit.txt','r') as f:
    qcis = f.read()
Qcir = QSIC2QCircuit(QCIS=qcis)
Qcir.draw()
# Out:
#      ┌──────────┐                           ░ ┌───────────┐┌─────────┐»
# q_0: ┤ Ry(-π/2) ├────────────────────────■──░─┤ Rz(-3π/4) ├┤ Ry(π/2) ├»
#      ├─────────┬┘┌─────────┐┌──────────┐ │  ░ └──┬──────┬─┘└─────────┘»
# q_1: ┤ Rz(π/4) ├─┤ Ry(π/2) ├┤ Rz(-π/4) ├─■──░────┤ √Xdg ├───────■─────»
#      ├─────────┴┐└─┬──────┬┘└──────────┘    ░    └──────┘       │     »
# q_2: ┤ Ry(-π/2) ├──┤ √Xdg ├─────────────────────────────────────■─────»
#      └──────────┘  └──────┘                                           »
# c: 3/═════════════════════════════════════════════════════════════════»
#                                                                       »
# «     ┌──────────┐     ░     ┌───────────┐ ┌─────────┐ ┌──────────┐            »
# «q_0: ┤ Rz(3π/4) ├─────░─────┤ Rz(-3π/4) ├─┤ Ry(π/2) ├─┤ Rz(3π/4) ├─────■──────»
# «     └──────────┘     ░     └┬──────────┤ └─────────┘ └──────────┘     │      »
# «q_1: ─────────────────░──────┤ Ry(-π/2) ├──────────────────────────────■──────»
# «     ┌─────────┐ ┌─────────┐ ├──────────┤┌───────────┐┌─────────┐ ┌──────────┐»
# «q_2: ┤ Rz(π/4) ├─┤ Ry(π/2) ├─┤ Rz(-π/4) ├┤ Rz(-3π/4) ├┤ Ry(π/2) ├─┤ Rz(3π/4) ├»
# «     └─────────┘ └─────────┘ └──────────┘└───────────┘└─────────┘ └──────────┘»
# «c: 3/═════════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «      ░ ┌───────────┐┌─────────┐┌──────────┐   ░    ┌───────────┐┌─────────┐»
# «q_0: ─░─┤ Rz(-3π/4) ├┤ Ry(π/2) ├┤ Rz(3π/4) ├───░────┤ Rz(-3π/4) ├┤ Ry(π/2) ├»
# «      ░ └───┬────┬──┘└─────────┘└──────────┘   ░    └┬─────────┬┘└─────────┘»
# «q_1: ─░─────┤ √X ├────────■────────────────────░─────┤ Ry(π/2) ├────────────»
# «      ░     └────┘        │        ┌────┐   ┌──────┐ └─────────┘            »
# «q_2: ─────────────────────■────────┤ √X ├───┤ √Xdg ├────────────────────────»
# «                                   └────┘   └──────┘                        »
# «c: 3/═══════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «     ┌──────────┐    ░ ┌──────────┐        ░      ┌─────────┐┌─────────┐»
# «q_0: ┤ Rz(3π/4) ├─■──░─┤ Ry(-π/2) ├────────░──────┤ Rz(π/4) ├┤ Ry(π/2) ├»
# «     └──────────┘ │  ░ └─┬──────┬─┘        ░      └─┬──────┬┘└─────────┘»
# «q_1: ─────────────■──░───┤ √Xdg ├───■──────░────────┤ √Xdg ├────────────»
# «                     ░   └──────┘   │ ┌──────────┐┌─┴──────┴┐           »
# «q_2: ───────────────────────────────■─┤ Ry(-π/2) ├┤ Ry(π/2) ├───────────»
# «                                      └──────────┘└─────────┘           »
# «c: 3/═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «     ┌──────────┐    ░ ┌───────────┐┌─────────┐┌──────────┐     ░     »
# «q_0: ┤ Rz(-π/4) ├─■──░─┤ Rz(-3π/4) ├┤ Ry(π/2) ├┤ Rz(3π/4) ├─────░─────»
# «     └──────────┘ │  ░ └──┬──────┬─┘└─────────┘└──────────┘     ░     »
# «q_1: ─────────────■──░────┤ √Xdg ├───────■──────────────────────░─────»
# «                     ░    └──────┘       │     ┌─────────┐ ┌─────────┐»
# «q_2: ────────────────────────────────────■─────┤ Rz(π/4) ├─┤ Ry(π/2) ├»
# «                                               └─────────┘ └─────────┘»
# «c: 3/═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «      ┌─────────┐                            ░  ┌──────────┐           »
# «q_0: ─┤ Ry(π/2) ├─────────────────────────■──░──┤ Ry(-π/2) ├───────────»
# «     ┌┴─────────┴┐┌─────────┐┌──────────┐ │  ░ ┌┴──────────┤┌─────────┐»
# «q_1: ┤ Rz(-3π/4) ├┤ Ry(π/2) ├┤ Rz(3π/4) ├─■──░─┤ Rz(-3π/4) ├┤ Ry(π/2) ├»
# «     └┬──────────┤└──┬────┬─┘└──────────┘    ░ └───────────┘└─────────┘»
# «q_2: ─┤ Rz(-π/4) ├───┤ √X ├────────────────────────────────────────────»
# «      └──────────┘   └────┘                                            »
# «c: 3/══════════════════════════════════════════════════════════════════»
# «                                                                       »
# «                         ░      ┌───────────┐┌─────────┐┌──────────┐    ░ »
# «q_0: ────────────────────░──────┤ Rz(-3π/4) ├┤ Ry(π/2) ├┤ Rz(3π/4) ├─■──░─»
# «     ┌──────────┐        ░      └──┬──────┬─┘└─────────┘└──────────┘ │  ░ »
# «q_1: ┤ Rz(3π/4) ├─■──────░─────────┤ √Xdg ├──────────────────────────■──░─»
# «     └──────────┘ │ ┌──────────┐┌──┴──────┴─┐┌─────────┐┌──────────┐    ░ »
# «q_2: ─────────────■─┤ Ry(-π/2) ├┤ Rz(-3π/4) ├┤ Ry(π/2) ├┤ Rz(3π/4) ├──────»
# «                    └──────────┘└───────────┘└─────────┘└──────────┘      »
# «c: 3/═════════════════════════════════════════════════════════════════════»
# «                                                                          »
# «     ┌─────────┐┌─────────┐ ┌──────────┐     ░     ┌───────────┐┌─────────┐»
# «q_0: ┤ Rz(π/4) ├┤ Ry(π/2) ├─┤ Rz(-π/4) ├─────░─────┤ Rz(-3π/4) ├┤ Ry(π/2) ├»
# «     └─┬──────┬┘└─────────┘ └──────────┘     ░     └──┬──────┬─┘└─────────┘»
# «q_1: ──┤ √Xdg ├──────■───────────────────────░────────┤ √Xdg ├─────────────»
# «       └──────┘      │     ┌───────────┐┌─────────┐ ┌─┴──────┴─┐┌─────────┐»
# «q_2: ────────────────■─────┤ Rz(-3π/4) ├┤ Ry(π/2) ├─┤ Rz(3π/4) ├┤ Ry(π/2) ├»
# «                           └───────────┘└─────────┘ └──────────┘└─────────┘»
# «c: 3/══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «     ┌──────────┐    ░  ┌─────────┐                             ░   »
# «q_0: ┤ Rz(3π/4) ├─■──░──┤ Ry(π/2) ├─────────────────────────────░───»
# «     └──────────┘ │  ░ ┌┴─────────┴┐┌─────────┐┌──────────┐     ░   »
# «q_1: ─────────────■──░─┤ Rz(-3π/4) ├┤ Ry(π/2) ├┤ Rz(3π/4) ├─■───░───»
# «                     ░ └───────────┘└─────────┘└──────────┘ │ ┌────┐»
# «q_2: ───────────────────────────────────────────────────────■─┤ √X ├»
# «                                                              └────┘»
# «c: 3/═══════════════════════════════════════════════════════════════»
# «                                                                    »
# «     ┌─────────┐┌─────────┐┌──────────┐    ░   ┌──────┐         ░     »
# «q_0: ┤ Rz(π/4) ├┤ Ry(π/2) ├┤ Rz(-π/4) ├─■──░───┤ √Xdg ├─────────░─────»
# «     └─┬──────┬┘└─────────┘└──────────┘ │  ░ ┌─┴──────┴┐        ░     »
# «q_1: ──┤ √Xdg ├─────────────────────────■──░─┤ Ry(π/2) ├─■──────░─────»
# «     ┌─┴──────┴┐                           ░ └─────────┘ │ ┌─────────┐»
# «q_2: ┤ Ry(π/2) ├─────────────────────────────────────────■─┤ Rz(π/4) ├»
# «     └─────────┘                                           └─────────┘»
# «c: 3/═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «      ┌─────────┐ ┌─────────┐ ┌──────────┐ ░ ┌─┐
# «q_0: ─┤ Rz(π/4) ├─┤ Ry(π/2) ├─┤ Rz(-π/4) ├─░─┤M├───
# «     ┌┴─────────┴┐├─────────┤ ├──────────┤ ░ └╥┘┌─┐
# «q_1: ┤ Rz(-3π/4) ├┤ Ry(π/2) ├─┤ Rz(3π/4) ├─░──╫─┤M├
# «     └┬─────────┬┘├─────────┴┐└───┬─┬────┘ ░  ║ └╥┘
# «q_2: ─┤ Ry(π/2) ├─┤ Rz(-π/4) ├────┤M├─────────╫──╫─
# «      └─────────┘ └──────────┘    └╥┘         ║  ║
# «c: 3/══════════════════════════════╩══════════╩══╩═
# «                                   2          0  1

# %%
_,qcis = solve(QCIS=qcis)
# Out:
# 初始化布局生效|score=141.0|map={0: 'Q39', 1: 'Q53', 2: 'Q44'}
